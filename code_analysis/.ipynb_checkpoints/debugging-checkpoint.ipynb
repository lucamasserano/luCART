# %%
cd ..
# Out:
# /Users/lucamasserano/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree

# %%
from luCART.classification_tree import tree
from luCART.random_forest import random_forest
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import cProfile

# %% [markdown]
# ## Generate synthetic data

# %%
def random_data(seed=7, size=200):

    np.random.seed(seed)
    two_dim_normal = pd.DataFrame(
        np.random.multivariate_normal(mean=[4, 8], cov=np.array([[2, 0], [0, 2]]), size=size//2))
    two_dim_normal2 = pd.DataFrame(
        np.random.multivariate_normal(mean=[8, 4], cov=np.array([[2, 0], [0, 2]]), size=size//2))
    two_dim_normal["y"] = 0
    two_dim_normal2["y"] = 1
    synthetic_data = pd.concat([two_dim_normal, two_dim_normal2], axis=0, ignore_index=True)
    synthetic_data.rename(columns={0: "0", 1: "1"}, inplace=True)
    
    colors = {0: "green", 1: "blue"}
    plt.scatter(synthetic_data['0'], synthetic_data['1'], c=synthetic_data.y.apply(lambda x: colors[x]))
    plt.xlabel(xlabel='0')
    plt.ylabel(ylabel='1')
    green_patch = mpatches.Patch(color='green', label="y = 0")
    blue_patch = mpatches.Patch(color='blue', label="y = 1")
    plt.legend(handles=[green_patch, blue_patch])
    plt.show()

    return synthetic_data

# %% [markdown]
# ### 2000 observations

# %%
synthetic_data_larger = random_data(size=2000)
synthetic_data_larger.shape
# Out:
# (2000, 3)

# %%
test_tree = tree.ClassificationTree(impurity_function="gini",
                                    data_source_type="dataframe",
                                    alpha=0.01,
                                    debug=True)

# %%
# %prun test_tree.fit(data=synthetic_data_larger, label="y")
# Out:
# ["(<df>['0'] < 5.928549563984921)", "(<df>['1'] < 4.541929651298272)", "(<df>['1'] >= 3.375033072853904)", "(<df>['0'] < 4.810011245214119)", "(<df>['0'] >= 4.810011245214119)"]
#
#  0 >= 4.810011245214119
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/data_handling/data_handler.py in node_misclassification_cost(self, node_key, decision_path, label)
#     153             if len(node_data.loc[node_data[label] == 1, :].index) >= (len(node_data.index) // 2):
# --> 154                 fraction_misclassified_points = len(node_data.loc[node_data[label] == 0, :].index) \
#     155                                                 / len(node_data.index)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-ec5eaddebfc5> in <module>
# ----> 1 get_ipython().run_line_magic('prun', 'test_tree.fit(data=synthetic_data_larger, label="y")')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-48> in prun(self, parameter_s, cell)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/execution.py in prun(self, parameter_s, cell)
#     315             arg_str += '\n' + cell
#     316         arg_str = self.shell.transform_cell(arg_str)
# --> 317         return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#     318
#     319     def _run_with_profiler(self, code, opts, namespace):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/execution.py in _run_with_profiler(self, code, opts, namespace)
#     337         prof = profile.Profile()
#     338         try:
# --> 339             prof = prof.runctx(code, namespace, namespace)
#     340             sys_exit = ''
#     341         except SystemExit:
#
# ~/opt/anaconda3/lib/python3.8/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/classification_tree/tree.py in fit(self, data, label)
#     508             logging.info("Building and pruning tree")
#     509             self.build_tree(impurity_function=self.impurity_function, decision_path=None)
# --> 510             self.prune_tree(alpha=self.alpha)
#     511             return
#     512         elif isinstance(self.alpha, (list, np.ndarray)):  # cv with given range of alpha
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/classification_tree/tree.py in prune_tree(self, alpha)
#     479         optimally_pruned = False
#     480         while not optimally_pruned:
# --> 481             nodes_pruning_cost_increases = self.pruning_step(self.root)
#     482             pruning_step_best_node_key, alpha_star = min(nodes_pruning_cost_increases, key=lambda elem: elem[1])
#     483             if alpha_star <= alpha:
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/classification_tree/tree.py in pruning_step(self, node, decision_path)
#     462
#     463         if node.key == "root":
# --> 464             return self.pruning_step(node=node.left, decision_path=[]) + \
#     465                 self.pruning_step(node=node.right, decision_path=[])
#     466         elif node.key not in self.leaves:
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/classification_tree/tree.py in pruning_step(self, node, decision_path)
#     467             decision_path += [node.decision_constructor(self.data_source_type)]
#     468             return [(node.key, self.prune_node_cost_increase(node=node, decision_path=decision_path))] + \
# --> 469                 self.pruning_step(node=node.left, decision_path=decision_path) + \
#     470                 self.pruning_step(node=node.right, decision_path=decision_path)
#     471         else:
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/classification_tree/tree.py in pruning_step(self, node, decision_path)
#     468             return [(node.key, self.prune_node_cost_increase(node=node, decision_path=decision_path))] + \
#     469                 self.pruning_step(node=node.left, decision_path=decision_path) + \
# --> 470                 self.pruning_step(node=node.right, decision_path=decision_path)
#     471         else:
#     472             # we are interested in the least cost increase. In this way leaves are ignored. None is a placeholder
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/classification_tree/tree.py in pruning_step(self, node, decision_path)
#     468             return [(node.key, self.prune_node_cost_increase(node=node, decision_path=decision_path))] + \
#     469                 self.pruning_step(node=node.left, decision_path=decision_path) + \
# --> 470                 self.pruning_step(node=node.right, decision_path=decision_path)
#     471         else:
#     472             # we are interested in the least cost increase. In this way leaves are ignored. None is a placeholder
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/classification_tree/tree.py in pruning_step(self, node, decision_path)
#     466         elif node.key not in self.leaves:
#     467             decision_path += [node.decision_constructor(self.data_source_type)]
# --> 468             return [(node.key, self.prune_node_cost_increase(node=node, decision_path=decision_path))] + \
#     469                 self.pruning_step(node=node.left, decision_path=decision_path) + \
#     470                 self.pruning_step(node=node.right, decision_path=decision_path)
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/classification_tree/tree.py in prune_node_cost_increase(self, node, decision_path)
#     442
#     443         node_misclassification_cost = \
# --> 444             self.data_handler.node_misclassification_cost(node_key=node.key,
#     445                                                           decision_path=decision_path,
#     446                                                           label=self.label)
#
# ~/Desktop/uni/cmu/statComp_36750/assignments-lucamasserano/classification-tree/luCART/data_handling/data_handler.py in node_misclassification_cost(self, node_key, decision_path, label)
#     159         except ZeroDivisionError:
#     160             print(decision_path, "\n\n", node_key)
# --> 161             raise ZeroDivisionError
#     162
#     163         logging.debug(
#
# ZeroDivisionError:

# %%
test_tree.show(test_tree.root)
# Out:
# root
# left:
#   0 < 5.928549563984921
#   left:
#     1 < 4.541929651298272
#     left:
#       1 < 3.375033072853904
#     right:
#       1 >= 3.375033072853904
#       left:
#         0 < 4.810011245214119
#         left:
#           0 < 4.614327308378462
#         right:
#           0 >= 4.614327308378462
#       right:
#         0 >= 4.810011245214119
#         left:
#           1 < 4.073684536185508
#           left:
#             1 < 4.007920326512566
#             left:
#               0 < 5.303763736363431
#             right:
#               0 >= 5.303763736363431
#               left:
#                 0 < 5.443994228701838
#               right:
#                 0 >= 5.443994228701838
#                 left:
#                   0 < 5.742063233024813
#                 right:
#                   0 >= 5.742063233024813
#           right:
#             1 >= 4.007920326512566
#         right:
#           1 >= 4.073684536185508
#   right:
#     1 >= 4.541929651298272
#     left:
#       1 < 5.8681520051985405
#       left:
#         0 < 5.079261788138007
#         left:
#           0 < 4.809962232998155
#         right:
#           0 >= 4.809962232998155
#           left:
#             0 < 4.837364132661035
#           right:
#             0 >= 4.837364132661035
#       right:
#         0 >= 5.079261788138007
#         left:
#           0 < 5.8551462627991135
#           left:
#             1 < 4.6869675703214995
#           right:
#             1 >= 4.6869675703214995
#             left:
#               1 < 5.461028061882542
#             right:
#               1 >= 5.461028061882542
#               left:
#                 1 < 5.5109145388093275
#               right:
#                 1 >= 5.5109145388093275
#                 left:
#                   1 < 5.581496272488126
#                 right:
#                   1 >= 5.581496272488126
#                   left:
#                     1 < 5.776244128776485
#                   right:
#                     1 >= 5.776244128776485
#         right:
#           0 >= 5.8551462627991135
#     right:
#       1 >= 5.8681520051985405
#       left:
#         1 < 6.692591893848546
#         left:
#           0 < 5.82886723021744
#           left:
#             1 < 6.69103634056253
#             left:
#               0 < 4.169693960143664
#             right:
#               0 >= 4.169693960143664
#               left:
#                 0 < 4.202327834732046
#               right:
#                 0 >= 4.202327834732046
#                 left:
#                   0 < 4.408571161898378
#                 right:
#                   0 >= 4.408571161898378
#                   left:
#                     0 < 5.284177743093563
#                   right:
#                     0 >= 5.284177743093563
#                     left:
#                       0 < 5.299723450050555
#                     right:
#                       0 >= 5.299723450050555
#           right:
#             1 >= 6.69103634056253
#         right:
#           0 >= 5.82886723021744
#       right:
#         1 >= 6.692591893848546
# right:
#   0 >= 5.928549563984921
#   left:
#     1 < 7.112754048592976
#     left:
#       1 < 6.823749134452186
#       left:
#         0 < 6.767961223612774
#         left:
#           1 < 4.681703941973604
#           left:
#             0 < 6.686782863937468
#           right:
#             0 >= 6.686782863937468
#             left:
#               0 < 6.694070278475982
#             right:
#               0 >= 6.694070278475982
#         right:
#           1 >= 4.681703941973604
#           left:
#             0 < 6.763227868815335
#             left:
#               1 < 4.687196814728244
#             right:
#               1 >= 4.687196814728244
#               left:
#                 1 < 5.560604530587135
#                 left:
#                   0 < 6.244345584589192
#                   left:
#                     0 < 6.137332701144446
#                     left:
#                       0 < 5.9938707677241325
#                     right:
#                       0 >= 5.9938707677241325
#                   right:
#                     0 >= 6.137332701144446
#                 right:
#                   0 >= 6.244345584589192
#               right:
#                 1 >= 5.560604530587135
#                 left:
#                   1 < 5.888034457259685
#                 right:
#                   1 >= 5.888034457259685
#                   left:
#                     0 < 6.535003885772266
#                   right:
#                     0 >= 6.535003885772266
#           right:
#             0 >= 6.763227868815335
#       right:
#         0 >= 6.767961223612774
#         left:
#           1 < 6.584835131295901
#         right:
#           1 >= 6.584835131295901
#           left:
#             1 < 6.612473207335279
#           right:
#             1 >= 6.612473207335279
#     right:
#       1 >= 6.823749134452186
#       left:
#         0 < 7.549458348598878
#         left:
#           0 < 7.0727043244902745
#         right:
#           0 >= 7.0727043244902745
#       right:
#         0 >= 7.549458348598878
#         left:
#           0 < 8.527870650639148
#         right:
#           0 >= 8.527870650639148
#   right:
#     1 >= 7.112754048592976
#     left:
#       0 < 8.142892596153292
#       left:
#         1 < 8.139855561193645
#         left:
#           0 < 6.716550248408061
#           left:
#             0 < 6.463278811963679
#           right:
#             0 >= 6.463278811963679
#         right:
#           0 >= 6.716550248408061
#           left:
#             0 < 8.007646681372096
#             left:
#               1 < 7.658339912679836
#             right:
#               1 >= 7.658339912679836
#           right:
#             0 >= 8.007646681372096
#       right:
#         1 >= 8.139855561193645
#     right:
#       0 >= 8.142892596153292
#       left:
#         1 < 10.339978845170512
#         left:
#           0 < 9.226577393475129
#         right:
#           0 >= 9.226577393475129
#       right:
#         1 >= 10.339978845170512
